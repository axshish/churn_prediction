# %% [markdown]
# # Modeling Walkthrough

# %%
from src.train import main as train_main
import argparse
args = argparse.Namespace(data_path='data/customers.csv', out='models/best_model.joblib', n_iter=10)
train_main(args)

# %% [markdown]
# Metrics from training will print above. Model is saved to `models/best_model.joblib`.
