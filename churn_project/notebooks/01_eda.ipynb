# %% [markdown]
# # EDA: Customer Churn (Dummy Data)

# %%
import pandas as pd
df = pd.read_csv('data/customers.csv')
df.head()

# %%
df.describe(include='all')

# %% [markdown]
# ## Class balance

# %%
df['churn'].value_counts(normalize=True)

# %% [markdown]
# You can extend this notebook with plots and deeper analysis.
